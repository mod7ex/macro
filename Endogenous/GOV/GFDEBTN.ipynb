# %%
import pandas as pd
import plotly.express as px

# %%
GFDEBTN_df = pd.read_csv('../data/GFDEBTN.csv')
GDP_df = pd.read_csv('../data/GDP.csv')

# GFDEBTN_df['DATE'] = pd.to_datetime(GFDEBTN_df['DATE'])
# GDP_df['DATE'] = pd.to_datetime(GDP_df['DATE'])

GFDEBTN_df.set_index('DATE', inplace=True)
GDP_df.set_index('DATE', inplace=True)

# %%
df = GFDEBTN_df.join(GDP_df, how="inner")

df['Debt / GDP Ratio'] = (df['GFDEBTN'] / (df['GDP'] * 1000)) * 100

df
# Out:
#              GFDEBTN        GDP  Debt / GDP Ratio
# DATE
# 1966-01-01    320999    795.734         40.339988
# 1966-04-01    316097    804.981         39.267635
# 1966-07-01    324748    819.638         39.620906
# 1966-10-01    329319    833.302         39.519766
# 1967-01-01    330947    844.170         39.203833
# ...              ...        ...               ...
# 2024-07-01  35464674  29511.664        120.171719
# 2024-10-01  36218605  29825.182        121.436325
# 2025-01-01  36214310  30042.113        120.545149
# 2025-04-01  36211469  30485.729        118.781706
# 2025-07-01  37637553  31098.027        121.028749
#
# [239 rows x 3 columns]

# %% [markdown]
# - **Plot**

# %%
fig = px.area(
    df,
    x=df.index,
    y="Debt / GDP Ratio",
)

fig.update_layout(
    title=dict(text='Debt / GDP Ratio'),
    width=1500,
    height=600,
    yaxis=dict(title="%"),
    hovermode="x unified",
    template="plotly_dark"
)

fig.show()
