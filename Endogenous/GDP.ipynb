# %% [markdown]
# ## Loading [GDP](https://fred.stlouisfed.org/series/GDP) data

# %%
from matplotlib import pyplot as plt
from matplotlib import dates as mpl_dates
import pandas as pd

# plt.style.use('dark_background')
plt.style.use('Solarize_Light2')

# import sys

# sys.path.append('../utils')

# %%
# plt.style.available

# %%
GDP_df = pd.read_csv('data/gdp/GDP.csv')

GDP_df['DATE'] = pd.to_datetime(GDP_df['DATE'])
GDP_df.set_index('DATE', inplace=True)
# GDP_df['DATE'] = pd.to_datetime(GDP_df['DATE']).dt.strftime("%d-%b-%Y")

GDP_df['^GDP %'] = GDP_df['GDP'].pct_change() * 100
GDP_df
# Out:
#                   GDP    ^GDP %
# DATE
# 1947-01-01    243.164       NaN
# 1947-04-01    245.968  1.153131
# 1947-07-01    249.585  1.470516
# 1947-10-01    259.745  4.070757
# 1948-01-01    265.742  2.308803
# ...               ...       ...
# 2023-07-01  27967.697  1.871805
# 2023-10-01  28296.967  1.177323
# 2024-01-01  28624.069  1.155961
# 2024-04-01  29016.714  1.371730
# 2024-07-01  29349.924  1.148338
#
# [311 rows x 2 columns]

# %% [markdown]
# ## Data Preview

# %%
GDP_df['GDP'].plot(
    figsize=(20, 7),
    xlabel='',
    ylabel='Billions of Dollars',
    title='GDP (Frequency: Quarterly)',
);

# %% [markdown]
# # Real GDP

# %%
real_GDP_df = pd.read_csv('data/gdp/A191RL1Q225SBEA.csv')

real_GDP_df['DATE'] = pd.to_datetime(real_GDP_df['DATE'])
real_GDP_df.set_index('DATE', inplace=True)
real_GDP_df.columns = ['Real GDP']

real_GDP_df
# Out:
#             Real GDP
# DATE
# 1947-04-01      -1.0
# 1947-07-01      -0.8
# 1947-10-01       6.4
# 1948-01-01       6.2
# 1948-04-01       6.8
# ...              ...
# 2023-07-01       4.4
# 2023-10-01       3.2
# 2024-01-01       1.6
# 2024-04-01       3.0
# 2024-07-01       2.8
#
# [310 rows x 1 columns]

# %%
real_GDP_df['Real GDP'].plot(
    figsize=(17, 5),
    xlabel='',
    ylabel='Percent Change from Preceding Period,',
    title='Real Gross Domestic Product (Frequency: Quarterly)',
);
