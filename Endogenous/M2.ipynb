# %%
import plotly.graph_objects as go
import pandas as pd
import plotly.express as px

# %%
M2_df = pd.read_csv('data/M2SL.csv')

M2_df.set_index('DATE', inplace=True)

M2_df['^ %'] = M2_df['M2SL'].pct_change() * 100

M2_df
# Out:
#                M2SL       ^ %
# DATE
# 1959-01-01    286.6       NaN
# 1959-02-01    287.7  0.383810
# 1959-03-01    289.2  0.521376
# 1959-04-01    290.1  0.311203
# 1959-05-01    292.2  0.723888
# ...             ...       ...
# 2025-07-01  22028.7  0.392845
# 2025-08-01  22108.3  0.361347
# 2025-09-01  22212.4  0.470864
# 2025-10-01  22298.0  0.385370
# 2025-11-01  22322.4  0.109427
#
# [803 rows x 2 columns]

# %% [markdown]
# - Plot

# %%
fig = px.line(
    M2_df,
    x=M2_df.index,
    y="M2SL",
    markers=True
)

fig.update_layout(
    title=dict(text='M2 money supply'),
    width=1500,
    height=600,
    yaxis=dict(title="Billions of dollars"),
    hovermode="x unified",
    template="plotly_dark"
)

fig.show()

# %% [markdown]
# - % change

# %%
fig = px.line(
    M2_df,
    x=M2_df.index,
    y='^ %',
    markers=True
)

fig.update_layout(
    title=dict(text='M2 money supply % Change MoM'),
    width=1500,
    height=600,
    yaxis=dict(title='%'),
    hovermode="x unified",
    template="plotly_dark"
)

fig.show()
